// %% [markdown]
// <!--
// https://www.wikiwand.com/en/Data
// https://www.merriam-webster.com/dictionary/data
// https://www.questionpro.com/blog/discrete-data-vs-continuous-data/#:~:text=Data%20that%20can%20only%20take,be%20broken%20into%20smaller%20parts.
// -->
// # Data
//
// <!--
// - The true value from data comes from is the change it inspires not the charts that it fills
// - The value of data comes from the decisions made from it, the actions it inspires, and the impact derived from those actions
// - The value of data comes from the decisions it inspires, the actions driven by the decsiions, and the impact derived from those actions
// - data means nothing without decisions from it.
// - decisions that drives the action inspired impact by decisions
// -->
// *Data* is measured quantities or qualities, observations, facts, or statistics of units of meaning or symbols.
// Data can be seen as the smallest units of factual information
// that can be used as a basis for calculation, reasoning, or discussion.
// Data is collected using techniques such as measurement, observation, query, or analysis,
// Once data is collected, it only becomes information suitable for making decisions once it has been analyzed and interpreted.
//
// <a id="levels-of-data"></a>
// ## Levels of Data
// Data values have four levels of measurement.
// There are two general categories of data.
//
// - Qualitative or discrete values that can be counted and has a limited number of values.
// - Quantitative or continuous values that can be measured and can take on an unlimited number of different values.
//
// These are the specific levels of data and actions that can be performed on them.
//
// Level|Type|Description |Actions|Examples
// :- |:-|:-|:-|:-
// Nominal |Qualitative|Values are classified into labels or categories|Count|Colors, countries, blood type
// Ordinal |Qualitative|Values rank higher or lower than others |Sort|Income range (low, medium high), grades, skill level
// Interval |Quantitative|Values have measures of difference between them, but do not start from 0|Take diifference|Temperature, time
// Ratio |Quantitative|Values have proportions of each other on a scale that begins at 0|Compute ratio|Weight, length, duration
// <!--
// collection of discrete or continuous values
// that convey information
// describing the quantity, quality, fact, statistics, other basic units of meaning, or
// simply sequences of symbols that may be further interpreted formally.
//
// Data is collected using techniques such as
// measurement, observation, query, or analysis, and is typically represented as numbers or characters which may be further processed.
//
// Data can be seen as the smallest units of factual information
// that can be used as a basis for calculation, reasoning, or discussion.
//
// Data can range from abstract ideas to concrete measurements, including, but not limited to, statistics.
//
// Thematically connected data presented in some relevant context can be viewed as information.
//
// Contextually connected pieces of information can then be described as data insights or intelligence.
//
// The stock of insights and intelligence that accumulates over time resulting from the synthesis of data into information, can then be described as knowledge.
//
// data is collected and analyzed; data only becomes information suitable for making decisions once it has been analyzed in some fashion.
//
//
// : factual information (such as measurements or statistics) used as a basis for reasoning, discussion, or calculation
//
// -->
